# %%
print("Please answer these Questions:")
print("1. What is Your favourite movie?")
print("Anna & Eilsa")
print("2. What is your dream career?")
print("My dreaam career is being a doctor.")
print("3. What is your School name?")
print("it is Obour STEM School.")
# Out:
# Please answer these Questions:
# 1. What is Your favourite movie?
# Anna & Eilsa
# 2. What is your dream career?
# My dreaam career is being a doctor.
# 3. What is your School name?
# it is Obour STEM School.
