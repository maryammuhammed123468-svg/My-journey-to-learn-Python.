# %%
name = input (print("What is your name?"))
age = input (print("How old are you?"))
subject = input(print("What is your favourite subject?"))
print(name, age, subject)
# Out:
# What is your name?
# NoneMariam
# How old are you?
# None16
# What is your favourite subject?
# NoneBiology
# Mariam  16 Biology
